# %% [markdown]
# ## Image Captioning
#
# __Lesson outline__
#
# In this lesson, we will learn about Image captioning. We will talk about the following topics:
#
# - Leveraging neural networks
# - Captions and the COCO dataset
# - Visualize and dataset
# - CNN-RNN model
# - The glue, feature vector
# - Tokenizing captions
# - Tokenizing words
# - RNN training
# - Video captioning

# %% [markdown]
# So far we have seen the CNN for image classification and object localization, and we have also seen the RNNs for the charecter generation for the sequential problems.
#
# ![image.png](attachment:3cf186bf-f6d3-4efe-8abe-7b898029bca3.png)

# %% [markdown]
# ## Leveraging Neural Networks
#
# CNN + RNN : Captioning
#
# COCO (Common Objects in context) Dataset : which contains the 2L images with pair of 5 captions which describes the images
#
# ![image.png](attachment:e9f08e74-7366-480c-91c3-6d5a0dbf8c16.png) ![image.png](attachment:1056ca31-d4bd-4703-9179-787edf4a935b.png) ![image.png](attachment:7f4bb69e-65c8-4fc4-a76b-5f1a63f73613.png)

# %% [markdown]
# ### Words to Vectors
# At this point, we know that you cannot directly feed words into an LSTM and expect it to be able to train or produce the correct output. These words first must be turned into a numerical representation so that a network can use normal loss functions and optimizers to calculate how "close" a predicted word and ground truth word (from a known, training caption) are. So, we typically turn a sequence of words into a sequence of numerical values; a vector of numbers where each number maps to a specific word in our vocabulary.
#
# To process words and create a vocabulary, we'll be using the Python text processing toolkit: NLTK. in the below video, we have one of our content developers, Arpan, explain the concept of word tokenization with NLTK.
#
# ![image.png](attachment:f0bd7a8f-40e9-44da-afa9-26b899af1846.png) ![image.png](attachment:7d612dcd-2ee1-43ba-8964-9da53fa97b43.png) ![image.png](attachment:83406c75-fc73-433a-a906-02f466e8a4e4.png)
#
#
#
# ## Decoder in the Image Captioning
#
# The decoder is made up of the LSTMs here in this problem of captioning the images
#
# ![image.png](attachment:db0421a4-ad30-4460-aad0-7991969d953c.png) ![image.png](attachment:2f4b76e1-d2d5-42a8-af1b-e2e39c7da235.png)

# %% [markdown]
# ## Video Captioning
# It is very similar to the image captioning. We know that the video is a combination of the images,  Each image frame will be providing the feature vector as the output so we just need to take the average of the frames because our RNN will not accept the multiple feature vectors as input. So feed the average of the multiple feature vectors to this to Decoder (LSTMs) as usual. Remaining process is same as it is for the image captioning.
#
# ![image.png](attachment:cb16bf89-298c-4672-a4da-3c375e5a7fec.png) ![image.png](attachment:91378e3c-5b06-47ac-aa9f-474632aaabc6.png)
