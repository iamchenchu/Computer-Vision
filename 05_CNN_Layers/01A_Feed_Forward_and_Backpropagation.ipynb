# %% [markdown]
# # Training a Neural Network
#
# The models are called neural networks because the perceptrons in the networks look like the nervous system in the brain that is why we call this as Neural Networks. Means the network accepts the inputs from the multiple neurons and then do some calculations and give us the output.
#
# ![image.png](attachment:6e88259e-a47f-400c-8bf9-ee33ccd4f823.png)
#
# In nervous sytem, the neurons in the brain takes inputs of impulses from the dendroits and process the outputs through the axons.

# %% [markdown]
# ## Let's try to convert 2 linear models to non linear models
#
# Now Imagien we have to calculate a point for ebing in a blue region in non linear model which is in the same place in the 2 linear models, then if we add both probabilities together, the values comes out to be 1.5 which is not a probability. There is a function called sigmoid which converts any number between 0 and 1.
#
# ![image.png](attachment:ec73b0cd-6af5-4c15-a02b-3d7298e3f391.png) ![image.png](attachment:e5d1fa52-a3c1-44a9-9b82-2808ce212eff.png)

# %% [markdown]
# ![image.png](attachment:996e645b-d7a4-45ea-b75b-65981b016d4c.png) ![image.png](attachment:57093aa8-6ac7-4ca4-9a54-0867a76cdda8.png) ![image.png](attachment:3e240ecc-6d0f-45cc-a8c7-45c3b314056b.png) ![image.png](attachment:a62db1d0-e92f-4998-a336-8d5e91675848.png) ![image.png](attachment:35356a1b-da3a-44e1-ae75-f4709204c447.png) ![image.png](attachment:a5503e94-842d-4ba8-8583-6cf35ebcc4f9.png)

# %% [markdown]
# ## Multiple layers
#
# Now, not all neural networks look like the one above. They can be way more complicated! In particular, we can do the following things:
#
# * Add more nodes to the input, hidden, and output layers.
# * Add more layers.
#
# ![image.png](attachment:d417440e-a9a7-4521-b637-11e22e779129.png) ![image.png](attachment:2d914d42-19bf-40f9-8d40-b0427cc2b0c6.png) ![image.png](attachment:41e03f1c-41e5-476c-83f3-f8a528825e01.png) ![image.png](attachment:62c3c98b-e696-4760-9979-161b4b663bd6.png) ![image.png](attachment:3e0ccc79-24d7-44f8-859d-f23655c4c56b.png)

# %% [markdown]
# ## Feedforward
# Feedforward is the process neural networks use to turn the input into an output. Let's study it more carefully, before we dive into how to train the networks.
#
# ![Screenshot 2024-08-18 at 12.04.59 PM.png](attachment:86e22c61-8252-4b98-a657-4478113d038d.png)
#
# ### Error Function
# Just as before, neural networks will produce an error function, which at the end, is what we'll be minimizing. The following video shows the error function for a neural network.
#
# ![image.png](attachment:ffb26145-e085-4597-865c-8e35c8f84fd6.png) ![image.png](attachment:86f6caab-8ab4-4f1d-a884-9476d21f2446.png)

# %% [markdown]
# # Back Propagation
#
# ow, we're ready to get our hands into training a neural network. For this, we'll use the method known as backpropagation. In a nutshell, backpropagation will consist of:
#
# * Doing a feedforward operation.
# * Comparing the output of the model with the desired output.
# * Calculating the error.
# * Running the feedforward operation backwards (backpropagation) to spread the error to each of the weights.
# * Use this to update the weights, and get a better model.
# * Continue this until we have a model that is good.
# Sounds more complicated than what it actually is. Let's take a look in the next few videos. The first video will show us a conceptual interpretation of what backpropagation is.
# ![image.png](attachment:2775cb68-2224-43fa-a6bd-beaac734c6e1.png)
# ![image.png](attachment:b6f51f57-495c-47f3-8edf-76040bd712d4.png) ![image.png](attachment:88f1a342-e799-4299-804b-3cb331c21642.png)
#
# ## Chain Rule
# ![image.png](attachment:961c1dbe-dec1-4e49-b292-3a255e727635.png) ![image.png](attachment:6adf7db2-4125-440a-9a3a-7cf0c0ee2068.png) ![image.png](attachment:bbccf648-8daa-4fb9-ade9-89cfc5a01231.png) ![image.png](attachment:3fc0b52d-2c94-4ad2-8a47-7e49a2804c20.png) ![image.png](attachment:761f5228-2769-4ef5-992d-c20e35930f3f.png)
